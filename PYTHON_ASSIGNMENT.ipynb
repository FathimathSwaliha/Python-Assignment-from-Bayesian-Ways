# %%
s=str(input('Enter the string:'))
s=s.lower()
reverse=s[::-1]
if s==reverse:
  print(True)
else:
  print(False)
# Out:
# Enter the string:Naan
# True

# %%
Input=str(input("Input:"))
Pattern=str(input("Pattern:"))
output=Input.count(Pattern)
output
# Out:
# Input:ABCDCDC
# Pattern:CD
# 2

# %%
A=[]
for i in range(1,11):
  print("Game",i,":")
  player1=str(input("Player1:"))
  player2=str(input("Player2:"))
  if (player1=="R" and player2=="S"):
    print("player1 wins")
    A.append(1)

  elif (player1=="P" and player2=="R"):
   print("player1 wins")
   A.append(1)
  elif (player1=="S" and player2=="P"):
    print("player1 wins")
    A.append(1)
  elif (player1==player2):
    print("Draw")
    A.append(0)
  else:
    print("player2 wins")
    A.append(2)
Player1score=A.count(1)
Player2score=A.count(2)
if Player1score > Player2score:
  print("Final Winner:Player1")
else:
    print("Final Winner:Player2")
# Out:
# Game 1 :
# Player1:R
# Player2:R
# Draw
# Game 2 :
# Player1:P
# Player2:P
# Draw
# Game 3 :
# Player1:S
# Player2:S
# Draw
# Game 4 :
# Player1:P
# Player2:S
# player2 wins
# Game 5 :
# Player1:P
# Player2:R
# player1 wins
# Game 6 :
# Player1:R
# Player2:P
# player2 wins
# Game 7 :
# Player1:R
# Player2:S
# player1 wins
# Game 8 :
# Player1:S
# Player2:P
# player1 wins
# Game 9 :
# Player1:S
# Player2:R
# player2 wins
# Game 10 :
# Player1:P
# Player2:R
# player1 wins
# Final Winner:Player1

# %%
import requests
import time

def fetch_bitcoin_price():
    url = "https://api.coindesk.com/v1/bpi/currentprice.json"
    response = requests.get(url)
    data = response.json()
    return data['bpi']['USD']['rate_float']


def collect_data():
    data_points = []
    previous_data_point = None
    count = 0
    while count < 288:
        usd_price = fetch_bitcoin_price()
        if usd_price != previous_data_point:
            data_points.append(usd_price)
            print("Data point", len(data_points), ":", usd_price)
            previous_data_point = usd_price
            count += 1
        time.sleep(5)
    data_points.sort()
    print("highest price is",data_points[-1])
    print("lowest price is",data_points[0])


collect_data()
# Out:
# Data point 1 : 43138.3928
# Data point 2 : 43146.4946
# Data point 3 : 43140.5383
# Data point 4 : 43138.7188
# Data point 5 : 43160.7161
# Data point 6 : 43157.2321
# Data point 7 : 43158.9773
# Data point 8 : 43154.3471
# Data point 9 : 43166.0253
# Data point 10 : 43162.9273
# Data point 11 : 43172.2088
# Data point 12 : 43180.8175
# Data point 13 : 43190.0981
# Data point 14 : 43202.9526
# Data point 15 : 43207.6481
# Data point 16 : 43198.706
# Data point 17 : 43185.7776
# Data point 18 : 43166.9662
# Data point 19 : 43152.4666
# Data point 20 : 43154.3461
# Data point 21 : 43135.1101
# Data point 22 : 43128.1818
# Data point 23 : 43137.3702
# Data point 24 : 43134.6449
# Data point 25 : 43183.6257
# Data point 26 : 43200.0139
# Data point 27 : 43196.1845
# Data point 28 : 43202.6469
# Data point 29 : 43210.1405
# Data point 30 : 43225.3794
# Data point 31 : 43237.7533
# Data point 32 : 43230.7843
# Data point 33 : 43230.3275
# Data point 34 : 43213.9055
# Data point 35 : 43226.3736
# Data point 36 : 43236.8287
# Data point 37 : 43227.5152
# Data point 38 : 43229.6852
# Data point 39 : 43218.2508
# Data point 40 : 43216.2645
# Data point 41 : 43216.108
# Data point 42 : 43222.8036
# Data point 43 : 43227.3691
# Data point 44 : 43246.262
# Data point 45 : 43265.6731
# Data point 46 : 43261.3533
# Data point 47 : 43265.1947
# Data point 48 : 43274.5045
# Data point 49 : 43273.7366
# Data point 50 : 43301.2328
# Data point 51 : 43301.4552
