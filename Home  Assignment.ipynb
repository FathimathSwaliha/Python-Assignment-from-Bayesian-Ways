# %%
import requests
import time

def fetch_bitcoin_price():
    url = "https://api.coindesk.com/v1/bpi/currentprice.json"
    response = requests.get(url)
    data = response.json()
    return data['bpi']['USD']['rate_float']


def collect_data():
    data_points = []
    previous_data_point = None
    count = 0
    while count < 300:
        usd_price = fetch_bitcoin_price()
        if usd_price != previous_data_point:
            data_points.append(usd_price)
            print("Data point", len(data_points), ":", usd_price)
            previous_data_point = usd_price
            count += 1
        time.sleep(300)
    data_points.sort()
    print("highest price is",data_points[-1])
    print("lowest price is",data_points[0])


collect_data()
# Out:
# Data point 1 : 42093.382
# Data point 2 : 42105.0987
# Data point 3 : 42100.5823
# Data point 4 : 42139.9715
# Data point 5 : 42147.9288
# Data point 6 : 42151.2022
# Data point 7 : 42148.4409
# Data point 8 : 42136.3254
# Data point 9 : 42122.6428
# Data point 10 : 42147.8682
# Data point 11 : 42197.3607
# Data point 12 : 42187.8846
# Data point 13 : 42204.3808
# Data point 14 : 42333.3227
# Data point 15 : 42331.0968
# Data point 16 : 42334.1889
# Data point 17 : 42291.8977
# Data point 18 : 42271.9615
# Data point 19 : 42310.6141
# Data point 20 : 42333.844
# Data point 21 : 42328.1392
# Data point 22 : 42300.3911
# Data point 23 : 42274.7973
# Data point 24 : 42281.1321
# Data point 25 : 42258.2482
# Data point 26 : 42247.3858
# Data point 27 : 42269.957
# Data point 28 : 42273.5696
# Data point 29 : 42282.047
# Data point 30 : 42266.8722
# Data point 31 : 42176.8393
# Data point 32 : 42183.4817
# Data point 33 : 42167.1293
# Data point 34 : 42156.3818
# Data point 35 : 42176.8015
# Data point 36 : 42205.2623
# Data point 37 : 42193.5893
# Data point 38 : 42183.8815
# Data point 39 : 42165.2738
# Data point 40 : 42177.6436
# Data point 41 : 42180.4753
# Data point 42 : 42193.1157
# Data point 43 : 42181.6162
# Data point 44 : 42202.8225
# Data point 45 : 42196.1427
# Data point 46 : 42214.1664
# Data point 47 : 42236.3263
# Data point 48 : 42232.5375
# Data point 49 : 42236.6626
# Data point 50 : 42203.529
# Data point 51 : 42208.7066
# Data point 52 : 42206.8286
# Data point 53 : 42239.2451
# Data point 54 : 42255.2546
# Data point 55 : 42273.841
# Data point 56 : 42262.437
# Data point 57 : 42271.8596
# Data point 58 : 42293.6707
# Data point 59 : 42301.2051
# Data point 60 : 42283.6723
# Data point 61 : 42281.0614
# Data point 62 : 42248.3664
# Data point 63 : 42308.3706
# Data point 64 : 42279.4169
# Data point 65 : 42306.0579
# Data point 66 : 42349.5488
# Data point 67 : 42408.5893
# Data point 68 : 42435.6406
# Data point 69 : 42396.9411
# Data point 70 : 42407.7188
# Data point 71 : 42396.5837
# Data point 72 : 42478.9436
# Data point 73 : 42487.6895
# Data point 74 : 42446.252
# Data point 167 : 42305.6939
# Data point 168 : 42299.1814
# Data point 169 : 42292.1572
# Data point 170 : 42318.5355
# Data point 171 : 42312.5978
# Data point 172 : 42295.6602
# Data point 173 : 42322.2296
# Data point 174 : 42315.5238
# Data point 175 : 42290.102
# Data point 176 : 42284.05
# Data point 177 : 42247.6208
# Data point 178 : 42277.5605
# Data point 179 : 42279.4726
# Data point 180 : 42190.9344
# Data point 181 : 42226.522
# Data point 182 : 42233.1006
# Data point 183 : 42267.4838
# Data point 184 : 42260.2033
# Data point 185 : 42272.0079
# Data point 186 : 42265.5019
# Data point 187 : 42229.5843
# Data point 188 : 42250.7505
# Data point 189 : 42248.4436
# Data point 190 : 42279.0695
# Data point 191 : 42265.6823
# Data point 192 : 42283.7438
# Data point 193 : 42227.215
# Data point 194 : 42238.4796
# Data point 195 : 42243.2596
# Data point 196 : 42237.5391
# Data point 197 : 42247.2026
# Data point 198 : 42237.697
# Data point 199 : 42231.1891
# Data point 200 : 42217.7412
# Data point 201 : 42233.3309
# Data point 202 : 42213.9365
# Data point 203 : 42222.6481
# Data point 204 : 42174.3735
# Data point 205 : 42173.5625
# Data point 206 : 42142.3523
# Data point 207 : 42110.2474
# Data point 208 : 42176.3204
# Data point 209 : 42202.5101
# Data point 210 : 42186.5228
# Data point 211 : 42175.9728
# Data point 212 : 42168.6007
# Data point 213 : 42149.7121
# Data point 214 : 42095.2399
# Data point 215 : 42064.8335
# Data point 216 : 42010.255
# Data point 217 : 41939.1467
# Data point 218 : 41959.2845
# Data point 219 : 41990.8364
# Data point 220 : 42038.506
# Data point 221 : 42078.7367
# Data point 222 : 42051.4384
# Data point 223 : 42036.386
# Data point 224 : 42008.9245
# Data point 225 : 41985.6514
# Data point 226 : 41974.7664
# Data point 227 : 41947.9304
# Data point 228 : 41902.4731
# Data point 229 : 41869.5205
# Data point 230 : 41856.8082
# Data point 231 : 41893.2082
# Data point 232 : 41891.906
# Data point 233 : 41897.564
# Data point 234 : 41918.6952
# Data point 235 : 41902.9892
# Data point 236 : 41942.9393
# Data point 237 : 41928.9142
# Data point 238 : 41940.7873
# Data point 239 : 41900.7313
# Data point 240 : 41899.4715
# Data point 241 : 41900.2239
# Data point 242 : 41868.2205
# Data point 243 : 41932.197
# Data point 244 : 41925.2061
# Data point 245 : 41924.3119
# Data point 246 : 41948.837
# Data point 247 : 41966.1695
# Data point 248 : 41963.5521
# Data point 249 : 41969.5291
# Data point 250 : 41960.1651
# Data point 251 : 41968.9582
# Data point 252 : 41975.6234
# Data point 253 : 41990.6183
# Data point 254 : 41983.2542
# Data point 255 : 41956.2756
# Data point 256 : 41967.2051
# Data point 257 : 41989.0826
# Data point 258 : 41975.5697
# Data point 259 : 41982.5981
# Data point 260 : 41987.8782
# Data point 261 : 41945.9879
# Data point 262 : 41879.137
# Data point 263 : 41827.9457
# Data point 264 : 41886.7493
# Data point 265 : 41813.1332
# Data point 266 : 41830.2145
# Data point 267 : 41913.1244
# Data point 268 : 41930.8603
# Data point 269 : 41923.8823
# Data point 270 : 41883.8057
# Data point 271 : 41916.5178
# Data point 272 : 41887.7569
# Data point 273 : 41849.1562
# Data point 274 : 41829.5534
# Data point 275 : 41803.6727
# Data point 276 : 41788.5584
# Data point 277 : 41860.1032
# Data point 278 : 41971.8884
# Data point 279 : 41977.958
# Data point 280 : 41948.4454
# Data point 281 : 41979.6043
# Data point 282 : 41964.3466
# Data point 283 : 41968.8902
# Data point 284 : 41910.9254
# Data point 285 : 41878.6593
# Data point 286 : 41890.6528
# Data point 287 : 41875.3331
# Data point 288 : 41894.5409
# Data point 289 : 41859.2794
# Data point 290 : 41842.9771
# Data point 291 : 41828.1402
# Data point 292 : 41863.0411
# Data point 293 : 41704.7772
# Data point 294 : 41672.3792
# Data point 295 : 41743.562
# Data point 296 : 41783.6525
# Data point 297 : 41770.2408
# Data point 298 : 41792.093
# Data point 299 : 41816.3439
# Data point 300 : 41808.7709
# highest price is 42646.7363
# lowest price is 41672.3792

# %%
s=str(input('Enter the string:'))
s=s.lower()
reverse=s[::-1]
if s==reverse:
  print(True)
else:
  print(False)
# Out:
# Enter the string:Naan
# True

# %%
Input=str(input("Input:"))
Pattern=str(input("Pattern:"))
output=Input.count(Pattern)
output
# Out:
# Input:ABCDCDC
# Pattern:CD
# 2

# %%
A=[]
for i in range(1,11):
  print("Game",i,":")
  player1=str(input("Player1:"))
  player2=str(input("Player2:"))
  if (player1=="R" and player2=="S"):
    print("player1 wins")
    A.append(1)

  elif (player1=="P" and player2=="R"):
   print("player1 wins")
   A.append(1)
  elif (player1=="S" and player2=="P"):
    print("player1 wins")
    A.append(1)
  elif (player1==player2):
    print("Draw")
    A.append(0)
  else:
    print("player2 wins")
    A.append(2)
Player1score=A.count(1)
Player2score=A.count(2)
if Player1score > Player2score:
  print("Final Winner:Player1")
else:
    print("Final Winner:Player2")
# Out:
# Game 1 :
# Player1:R
# Player2:R
# Draw
# Game 2 :
# Player1:R
# Player2:P
# player2 wins
# Game 3 :
# Player1:R
# Player2:S
# player1 wins
# Game 4 :
# Player1:P
# Player2:R
# player1 wins
# Game 5 :
# Player1:P
# Player2:P
# Draw
# Game 6 :
# Player1:P
# Player2:S
# player2 wins
# Game 7 :
# Player1:S
# Player2:R
# player2 wins
# Game 8 :
# Player1:S
# Player2:P
# player1 wins
# Game 9 :
# Player1:S
# Player2:S
# Draw
# Game 10 :
# Player1:P
# Player2:S
# player2 wins
# Final Winner:Player2
